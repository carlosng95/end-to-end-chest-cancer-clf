# %%
d = {'key': 'value', 'key1': 'value1'}

# %%
from box import ConfigBox

# %%
d2 = ConfigBox(d)

# %%
d2.key
# Out:
# 'value'

# %%
import gdown

# %%
url = 'https://drive.google.com/file/d/1z0mreUtRmR-P-magILsDR3T7M6IkGXtY/view?usp=sharing'

# %%
file_id = url.split('/')[-2]

prefix = 'https://drive.google.com/uc?/export=download&id='

gdown.download(prefix+file_id, 'Chest-CT-Scan-data.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY&confirm=t&uuid=46563b31-5d5b-4171-a785-160f8dc51b22
# To: /Users/carlosgordilloolivera/codigos_varios/end-to-end-chest-cancer-clf/research/Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:04<00:00, 12.0MB/s]
# 'Chest-CT-Scan-data.zip'
